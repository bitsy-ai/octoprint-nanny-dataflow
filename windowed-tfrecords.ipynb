# %%
# %pip install tensorflow-transform
# Out:
# Requirement already satisfied: tensorflow-transform in /root/apache-beam-custom/lib/python3.7/site-packages (0.26.0)
# Requirement already satisfied: apache-beam[gcp]!=2.26.*,<3,>=2.25 in /root/apache-beam-custom/packages/beam/sdks/python (from tensorflow-transform) (2.25.0)
# Requirement already satisfied: tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<2.4,>=1.15.2 in /root/apache-beam-custom/lib/python3.7/site-packages (from tensorflow-transform) (2.3.0)
# Requirement already satisfied: tfx-bsl<0.27,>=0.26 in /root/apache-beam-custom/lib/python3.7/site-packages (from tensorflow-transform) (0.26.1)
# Requirement already satisfied: protobuf<4,>=3.9.2 in /root/apache-beam-custom/lib/python3.7/site-packages (from tensorflow-transform) (3.12.2)
# Requirement already satisfied: pyarrow<0.18,>=0.17 in /root/apache-beam-custom/lib/python3.7/site-packages (from tensorflow-transform) (0.17.1)
# Requirement already satisfied: tensorflow-metadata<0.27,>=0.26 in /root/apache-beam-custom/lib/python3.7/site-packages (from tensorflow-transform) (0.26.0)
# Requirement already satisfied: numpy<2,>=1.16 in /root/apache-beam-custom/lib/python3.7/site-packages (from tensorflow-transform) (1.17.3)
# Requirement already satisfied: pydot<2,>=1.2 in /root/apache-beam-custom/lib/python3.7/site-packages (from tensorflow-transform) (1.4.1)
# Requirement already satisfied: absl-py<0.11,>=0.9 in /root/apache-beam-custom/lib/python3.7/site-packages (from tensorflow-transform) (0.10.0)
# Requirement already satisfied: six<2,>=1.12 in /root/apache-beam-custom/lib/python3.7/site-packages (from tensorflow-transform) (1.15.0)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /root/apache-beam-custom/lib/python3.7/site-packages (from apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (1.7)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in /root/apache-beam-custom/lib/python3.7/site-packages (from apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (0.3.1.1)
# Requirement already satisfied: fastavro<2,>=0.21.4 in /root/apache-beam-custom/lib/python3.7/site-packages (from apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (1.0.0.post1)
# Requirement already satisfied: future<1.0.0,>=0.18.2 in /root/apache-beam-custom/lib/python3.7/site-packages (from apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (0.18.2)
# Requirement already satisfied: grpcio<2,>=1.29.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (1.29.0)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (2.5.8)
# Requirement already satisfied: httplib2<0.18.0,>=0.8 in /root/apache-beam-custom/lib/python3.7/site-packages (from apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (0.12.0)
# Requirement already satisfied: mock<3.0.0,>=1.0.1 in /root/apache-beam-custom/lib/python3.7/site-packages (from apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (2.0.0)
# Requirement already satisfied: pymongo<4.0.0,>=3.8.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (3.9.0)
# Requirement already satisfied: oauth2client<5,>=2.0.1 in /root/apache-beam-custom/lib/python3.7/site-packages (from apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (4.1.3)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (2.8.1)
# Requirement already satisfied: pytz>=2018.3 in /root/apache-beam-custom/lib/python3.7/site-packages (from apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (2019.3)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (2.25.0)
# Requirement already satisfied: typing-extensions<3.8.0,>=3.7.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (3.7.4.3)
# Requirement already satisfied: avro-python3!=1.9.2,<1.10.0,>=1.8.1 in /root/apache-beam-custom/lib/python3.7/site-packages (from apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (1.8.2)
# Requirement already satisfied: cachetools<5,>=3.1.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (4.2.0)
# Requirement already satisfied: google-apitools<0.5.32,>=0.5.31 in /root/apache-beam-custom/lib/python3.7/site-packages (from apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (0.5.31)
# Requirement already satisfied: google-auth<2,>=1.18.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (1.24.0)
# Requirement already satisfied: google-cloud-datastore<2,>=1.7.1 in /root/apache-beam-custom/lib/python3.7/site-packages (from apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (1.7.4)
# Requirement already satisfied: google-cloud-pubsub<2,>=0.39.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (1.0.2)
# Requirement already satisfied: google-cloud-bigquery<2,>=1.6.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (1.26.1)
# Requirement already satisfied: google-cloud-core<2,>=0.28.1 in /root/apache-beam-custom/lib/python3.7/site-packages (from apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (1.4.1)
# Requirement already satisfied: google-cloud-bigtable<2,>=0.31.1 in /root/apache-beam-custom/lib/python3.7/site-packages (from apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (1.0.0)
# Requirement already satisfied: google-cloud-spanner<2,>=1.13.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (1.19.1)
# Requirement already satisfied: grpcio-gcp<1,>=0.2.2 in /root/apache-beam-custom/lib/python3.7/site-packages (from apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (0.2.2)
# Requirement already satisfied: google-cloud-dlp<2,>=0.12.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (1.0.0)
# Requirement already satisfied: google-cloud-language<2,>=1.3.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (1.3.0)
# Requirement already satisfied: google-cloud-videointelligence<2,>=1.8.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (1.16.1)
# Requirement already satisfied: google-cloud-vision<2,>=0.38.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (1.0.0)
# Requirement already satisfied: google-cloud-build<3,>=2.0.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (2.0.0)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<2.4,>=1.15.2->tensorflow-transform) (2.10.0)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in /root/apache-beam-custom/lib/python3.7/site-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<2.4,>=1.15.2->tensorflow-transform) (1.1.2)
# Requirement already satisfied: wheel>=0.26 in /root/apache-beam-custom/lib/python3.7/site-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<2.4,>=1.15.2->tensorflow-transform) (0.36.2)
# Requirement already satisfied: scipy==1.4.1 in /root/apache-beam-custom/lib/python3.7/site-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<2.4,>=1.15.2->tensorflow-transform) (1.4.1)
# Requirement already satisfied: google-pasta>=0.1.8 in /root/apache-beam-custom/lib/python3.7/site-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<2.4,>=1.15.2->tensorflow-transform) (0.2.0)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<2.4,>=1.15.2->tensorflow-transform) (2.3.0)
# Requirement already satisfied: gast==0.3.3 in /root/apache-beam-custom/lib/python3.7/site-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<2.4,>=1.15.2->tensorflow-transform) (0.3.3)
# Requirement already satisfied: astunparse==1.6.3 in /root/apache-beam-custom/lib/python3.7/site-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<2.4,>=1.15.2->tensorflow-transform) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<2.4,>=1.15.2->tensorflow-transform) (1.1.0)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<2.4,>=1.15.2->tensorflow-transform) (2.4.0)
# Requirement already satisfied: wrapt>=1.11.1 in /root/apache-beam-custom/lib/python3.7/site-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<2.4,>=1.15.2->tensorflow-transform) (1.12.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /root/apache-beam-custom/lib/python3.7/site-packages (from tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<2.4,>=1.15.2->tensorflow-transform) (3.3.0)
# Requirement already satisfied: pandas<2,>=1.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from tfx-bsl<0.27,>=0.26->tensorflow-transform) (1.2.0)
# Requirement already satisfied: google-api-python-client<2,>=1.7.11 in /root/apache-beam-custom/lib/python3.7/site-packages (from tfx-bsl<0.27,>=0.26->tensorflow-transform) (1.12.8)
# Requirement already satisfied: tensorflow-serving-api!=2.0.*,!=2.1.*,!=2.2.*,!=2.4.*,<3,>=1.15 in /root/apache-beam-custom/lib/python3.7/site-packages (from tfx-bsl<0.27,>=0.26->tensorflow-transform) (2.3.0)
# Requirement already satisfied: setuptools in /root/apache-beam-custom/lib/python3.7/site-packages (from protobuf<4,>=3.9.2->tensorflow-transform) (47.1.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from tensorflow-metadata<0.27,>=0.26->tensorflow-transform) (1.52.0)
# Requirement already satisfied: pyparsing>=2.1.4 in /root/apache-beam-custom/lib/python3.7/site-packages (from pydot<2,>=1.2->tensorflow-transform) (2.4.7)
# Requirement already satisfied: docopt in /root/apache-beam-custom/lib/python3.7/site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (0.6.2)
# Requirement already satisfied: pbr>=0.11 in /root/apache-beam-custom/lib/python3.7/site-packages (from mock<3.0.0,>=1.0.1->apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (5.5.1)
# Requirement already satisfied: pyasn1>=0.1.7 in /root/apache-beam-custom/lib/python3.7/site-packages (from oauth2client<5,>=2.0.1->apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (0.4.8)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /root/apache-beam-custom/lib/python3.7/site-packages (from oauth2client<5,>=2.0.1->apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (0.2.8)
# Requirement already satisfied: rsa>=3.1.4 in /root/apache-beam-custom/lib/python3.7/site-packages (from oauth2client<5,>=2.0.1->apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (4.6)
# Requirement already satisfied: idna<3,>=2.5 in /root/apache-beam-custom/lib/python3.7/site-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /root/apache-beam-custom/lib/python3.7/site-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /root/apache-beam-custom/lib/python3.7/site-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /root/apache-beam-custom/lib/python3.7/site-packages (from requests<3.0.0,>=2.24.0->apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (1.26.2)
# Requirement already satisfied: fasteners>=0.14 in /root/apache-beam-custom/lib/python3.7/site-packages (from google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (0.15)
# Requirement already satisfied: google-api-core[grpc]<2.0.0dev,>=1.6.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from google-cloud-datastore<2,>=1.7.1->apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (1.22.0)
# Requirement already satisfied: grpc-google-iam-v1<0.13dev,>=0.12.3 in /root/apache-beam-custom/lib/python3.7/site-packages (from google-cloud-pubsub<2,>=0.39.0->apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (0.12.3)
# Requirement already satisfied: google-resumable-media<2.0dev,>=0.5.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from google-cloud-bigquery<2,>=1.6.0->apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (1.2.0)
# Requirement already satisfied: proto-plus>=0.4.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from google-cloud-build<3,>=2.0.0->apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (1.13.0)
# Requirement already satisfied: libcst>=0.2.5 in /root/apache-beam-custom/lib/python3.7/site-packages (from google-cloud-build<3,>=2.0.0->apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (0.3.15)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from tensorboard<3,>=2.3.0->tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<2.4,>=1.15.2->tensorflow-transform) (1.7.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /root/apache-beam-custom/lib/python3.7/site-packages (from tensorboard<3,>=2.3.0->tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<2.4,>=1.15.2->tensorflow-transform) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /root/apache-beam-custom/lib/python3.7/site-packages (from tensorboard<3,>=2.3.0->tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<2.4,>=1.15.2->tensorflow-transform) (3.3.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /root/apache-beam-custom/lib/python3.7/site-packages (from tensorboard<3,>=2.3.0->tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<2.4,>=1.15.2->tensorflow-transform) (0.4.2)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from google-api-python-client<2,>=1.7.11->tfx-bsl<0.27,>=0.26->tensorflow-transform) (3.0.1)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /root/apache-beam-custom/lib/python3.7/site-packages (from google-api-python-client<2,>=1.7.11->tfx-bsl<0.27,>=0.26->tensorflow-transform) (0.0.4)
# Requirement already satisfied: monotonic>=0.1 in /root/apache-beam-custom/lib/python3.7/site-packages (from fasteners>=0.14->google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (1.5)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0; python_version >= "3.5" in /root/apache-beam-custom/lib/python3.7/site-packages (from google-resumable-media<2.0dev,>=0.5.0->google-cloud-bigquery<2,>=1.6.0->apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (1.1.0)
# Requirement already satisfied: pyyaml>=5.2 in /root/apache-beam-custom/lib/python3.7/site-packages (from libcst>=0.2.5->google-cloud-build<3,>=2.0.0->apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (5.3.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from libcst>=0.2.5->google-cloud-build<3,>=2.0.0->apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (0.6.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /root/apache-beam-custom/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<2.4,>=1.15.2->tensorflow-transform) (3.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<2.4,>=1.15.2->tensorflow-transform) (1.3.0)
# Requirement already satisfied: cffi>=1.0.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from google-crc32c<2.0dev,>=1.0; python_version >= "3.5"->google-resumable-media<2.0dev,>=0.5.0->google-cloud-bigquery<2,>=1.6.0->apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (1.14.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from typing-inspect>=0.4.0->libcst>=0.2.5->google-cloud-build<3,>=2.0.0->apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (0.4.3)
# Requirement already satisfied: zipp>=0.5 in /root/apache-beam-custom/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<2.4,>=1.15.2->tensorflow-transform) (3.4.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /root/apache-beam-custom/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow!=2.0.*,!=2.1.*,!=2.2.*,<2.4,>=1.15.2->tensorflow-transform) (3.1.0)
# Requirement already satisfied: pycparser in /root/apache-beam-custom/lib/python3.7/site-packages (from cffi>=1.0.0->google-crc32c<2.0dev,>=1.0; python_version >= "3.5"->google-resumable-media<2.0dev,>=0.5.0->google-cloud-bigquery<2,>=1.6.0->apache-beam[gcp]!=2.26.*,<3,>=2.25->tensorflow-transform) (2.20)
# WARNING: You are using pip version 20.1.1; however, version 20.3.3 is available.
# You should consider upgrading via the '/root/apache-beam-custom/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import apache_beam as beam
from apache_beam import window
from apache_beam.runners.interactive import interactive_runner
import apache_beam.runners.interactive.interactive_beam as ib
from apache_beam.transforms import trigger
from apache_beam.options import pipeline_options
from apache_beam.options.pipeline_options import GoogleCloudOptions
from tensorflow_transform.beam import impl as beam_impl

import google.auth
import json
import pandas as pd
import base64
import io
import os
import tensorflow as tf
from tensorflow_transform.coders import example_proto_coder
from tensorflow_transform.tf_metadata import dataset_metadata
from tensorflow_transform.tf_metadata import schema_utils
import gzip

# The Google Cloud PubSub topic that we are reading from for this example.
topic = "projects/print-nanny/topics/bounding-boxes-dev"

# So that Pandas Dataframes do not truncate data...
pd.set_option('display.max_colwidth', 20)

# %%
# def run_transformation_pipeline(args):
#     options = beam.pipeline.PipelineOptions(flags=[], **args)
#     # Sets the pipeline mode to streaming, so we can stream the data from PubSub.
#     options.view_as(pipeline_options.StandardOptions).streaming = True

# %%
# Setting up the Beam pipeline options.
options = pipeline_options.PipelineOptions()

# Sets the pipeline mode to streaming, so we can stream the data from PubSub.
options.view_as(pipeline_options.StandardOptions).streaming = True

options.view_as(GoogleCloudOptions).region = 'us-central1'
dataflow_gcs_location = 'gs://print-nanny-dev/dataflow/bounding-box-events'

options.view_as(GoogleCloudOptions).staging_location = '%s/staging' % dataflow_gcs_location
options.view_as(GoogleCloudOptions).temp_location = '%s/temp' % dataflow_gcs_location
options.view_as(pipeline_options.SetupOptions).sdk_location = (
    '/root/apache-beam-custom/packages/beam/sdks/python/dist/apache-beam-%s.tar.gz' %
    beam.version.__version__)

# Sets the project to the default project in your current Google Cloud environment.
# The project will be used for creating a subscription to the PubSub topic.
_, options.view_as(GoogleCloudOptions).project = google.auth.default()

# %%
ib.options.recording_duration = '1m'

# %%
p = beam.Pipeline(interactive_runner.InteractiveRunner(), options=options)

# %%
raw_data_metadata = dataset_metadata.DatasetMetadata(
      schema_utils.schema_from_feature_spec({
        'ts': tf.io.FixedLenFeature([], tf.int64),
        'device_id': tf.io.FixedLenFeature([], tf.int64),
        'device_cloudiot_name': tf.io.FixedLenFeature([], tf.string),
        'user_id': tf.io.FixedLenFeature([], tf.int64),
        'calibration_x0': tf.io.FixedLenFeature([], tf.float32),
        'calibration_y0': tf.io.FixedLenFeature([], tf.float32),
        'calibration_x1': tf.io.FixedLenFeature([], tf.float32),
        'calibration_y1': tf.io.FixedLenFeature([], tf.float32),
        'num_detections': tf.io.FixedLenFeature([], tf.int64),
        'detection_classes': tf.io.FixedLenFeature([], tf.int64),
        'detection_scores': tf.io.FixedLenFeature([], tf.float32),
        'original_image': tf.io.FixedLenFeature([], tf.string),
        "detection_boxes_x0": tf.io.FixedLenFeature([], tf.float32),
        "detection_boxes_y0": tf.io.FixedLenFeature([], tf.float32),
        "detection_boxes_x1": tf.io.FixedLenFeature([], tf.float32),
        "detection_boxes_y1": tf.io.FixedLenFeature([], tf.float32),
    }))



class WindowedWritesFn(beam.DoFn):
    """write one file per window/key"""
    def __init__(self, outdir):
        self.outdir = outdir

    def process(self, element):
        (window, elements) = element
        window_start = str(window.start.to_rfc3339())
        window_end = str(window.end.to_rfc3339())
        return (elements | beam.io.tfrecordio.WriteToTFRecord(
            file_path_prefix=os.path.join(self.outdir, f'{window_start}-{window_end}'),
            num_shards=1,
            shard_name_template='',
            file_name_suffix=".tfrecords.gz",
            coder=example_proto_coder.ExampleProtoCoder(raw_data_metadata.schema)
        ))

class AddWindowingInfoFn(beam.DoFn):
  """output tuple of window(key) + element(value)"""
  def process(self, element, window=beam.DoFn.WindowParam):
    yield (window, element)

WINDOW_SIZE = 60

def preprocess_features(input_bytes):
    fileobj = io.BytesIO(input_bytes)
    with gzip.GzipFile(fileobj=fileobj, mode='r') as f:
        output_features = f.read()
    output_features = json.loads(output_features)
    output_features["original_image"] = base64.b64decode(output_features["original_image"])
    output_features["detection_boxes_x0"] = [x[0] for x in output_features["detection_boxes"]]
    output_features["detection_boxes_y0"] = [x[1] for x in output_features["detection_boxes"]]
    output_features["detection_boxes_x1"] = [x[2] for x in output_features["detection_boxes"]]
    output_features["detection_boxes_y1"] = [x[3] for x in output_features["detection_boxes"]]
    
    output_features["calibration_x0"] = output_features["calibration"][0]
    output_features["calibration_y0"] = output_features["calibration"][1]
    output_features["calibration_x1"] = output_features["calibration"][2]
    output_features["calibration_y1"] = output_features["calibration"][3]

    del output_features["calibration"]
    del output_features["detection_boxes"]
    return output_features

windowed_dataset = (p
    | "Read ObjectDetectEvents" >> beam.io.ReadFromPubSub(topic=topic) \
    | "Deserialize data" >> beam.Map(preprocess_features) \
    #| "Add timestamps" >> beam.Map(lambda x: beam.window.TimestampedValue(x, x['ts'])) \
    | "Window" >>  beam.WindowInto(window.FixedWindows(WINDOW_SIZE)) \
    | "Add Window Info" >> beam.ParDo(AddWindowingInfoFn()) \
    | 'Group By Window' >> beam.GroupByKey()  \
    | 'Write TFRecords' >> beam.io.tfrecordio.WriteToTFRecord(
                file_path_prefix=dataflow_gcs_location,
                file_name_suffix=".tfrecords.gz",
                coder=example_proto_coder.ExampleProtoCoder(raw_data_metadata.schema))
)

# windows, windowed_elements = windowed_dataset
# window_start = str(window.start.to_rfc3339())
# window_end = str(window.end.to_rfc3339())                  

# tf_record_writer = windowed_dataset | 'Write TFRecords' >> beam.io.tfrecordio.WriteToTFRecord(
#             file_path_prefix=dataflow_gcs_location,
#             file_name_suffix=".tfrecords.gz",
#             coder=example_proto_coder.ExampleProtoCoder(raw_data_metadata.schema))

# %%
ib.show_graph(p)
# Out:
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div id="progress_indicator_18bea3a62b6f7d91cba1711ec7149d29" class="spinner-border text-info" role="status">
#             </div>
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.42.3 (20191010.1750)
#  -->
# <!-- Title: G Pages: 1 -->
# <svg width="187pt" height="952pt"
#  viewBox="0.00 0.00 187.00 952.09" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 948.09)">
# <title>G</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-948.09 183,-948.09 183,4 -4,4"/>
# <!-- [7]: Read ObjectDetectEvents -->
# <g id="node1" class="node">
# <title>[7]: Read ObjectDetectEvents</title>
# <polygon fill="none" stroke="blue" points="179,-944.09 0,-944.09 0,-908.09 179,-908.09 179,-944.09"/>
# <text text-anchor="middle" x="89.5" y="-922.39" font-family="Times,serif" font-size="14.00" fill="blue">[7]: Read ObjectDetectEvents</text>
# </g>
# <!-- pcoll498 -->
# <g id="node2" class="node">
# <title>pcoll498</title>
# <ellipse fill="none" stroke="blue" cx="89.5" cy="-854.09" rx="18" ry="18"/>
# </g>
# <!-- [7]: Read ObjectDetectEvents&#45;&gt;pcoll498 -->
# <g id="edge1" class="edge">
# <title>[7]: Read ObjectDetectEvents&#45;&gt;pcoll498</title>
# <path fill="none" stroke="black" d="M89.5,-907.78C89.5,-900.07 89.5,-890.8 89.5,-882.2"/>
# <polygon fill="black" stroke="black" points="93,-882.19 89.5,-872.19 86,-882.19 93,-882.19"/>
# </g>
# <!-- [7]: Deserialize data -->
# <g id="node3" class="node">
# <title>[7]: Deserialize data</title>
# <polygon fill="none" stroke="blue" points="153,-800.09 26,-800.09 26,-764.09 153,-764.09 153,-800.09"/>
# <text text-anchor="middle" x="89.5" y="-778.39" font-family="Times,serif" font-size="14.00" fill="blue">[7]: Deserialize data</text>
# </g>
# <!-- pcoll498&#45;&gt;[7]: Deserialize data -->
# <g id="edge2" class="edge">
# <title>pcoll498&#45;&gt;[7]: Deserialize data</title>
# <path fill="none" stroke="black" d="M89.5,-835.78C89.5,-828.07 89.5,-818.8 89.5,-810.2"/>
# <polygon fill="black" stroke="black" points="93,-810.19 89.5,-800.19 86,-810.19 93,-810.19"/>
# </g>
# <!-- pcoll1135 -->
# <g id="node4" class="node">
# <title>pcoll1135</title>
# <ellipse fill="none" stroke="blue" cx="89.5" cy="-710.09" rx="18" ry="18"/>
# </g>
# <!-- [7]: Deserialize data&#45;&gt;pcoll1135 -->
# <g id="edge3" class="edge">
# <title>[7]: Deserialize data&#45;&gt;pcoll1135</title>
# <path fill="none" stroke="black" d="M89.5,-763.78C89.5,-756.07 89.5,-746.8 89.5,-738.2"/>
# <polygon fill="black" stroke="black" points="93,-738.19 89.5,-728.19 86,-738.19 93,-738.19"/>
# </g>
# <!-- [7]: Window -->
# <g id="node5" class="node">
# <title>[7]: Window</title>
# <polygon fill="none" stroke="blue" points="133,-656.09 46,-656.09 46,-620.09 133,-620.09 133,-656.09"/>
# <text text-anchor="middle" x="89.5" y="-634.39" font-family="Times,serif" font-size="14.00" fill="blue">[7]: Window</text>
# </g>
# <!-- pcoll1135&#45;&gt;[7]: Window -->
# <g id="edge4" class="edge">
# <title>pcoll1135&#45;&gt;[7]: Window</title>
# <path fill="none" stroke="black" d="M89.5,-691.78C89.5,-684.07 89.5,-674.8 89.5,-666.2"/>
# <polygon fill="black" stroke="black" points="93,-666.19 89.5,-656.19 86,-666.19 93,-666.19"/>
# </g>
# <!-- pcoll6870 -->
# <g id="node6" class="node">
# <title>pcoll6870</title>
# <ellipse fill="none" stroke="blue" cx="89.5" cy="-566.09" rx="18" ry="18"/>
# </g>
# <!-- [7]: Window&#45;&gt;pcoll6870 -->
# <g id="edge5" class="edge">
# <title>[7]: Window&#45;&gt;pcoll6870</title>
# <path fill="none" stroke="black" d="M89.5,-619.78C89.5,-612.07 89.5,-602.8 89.5,-594.2"/>
# <polygon fill="black" stroke="black" points="93,-594.19 89.5,-584.19 86,-594.19 93,-594.19"/>
# </g>
# <!-- [7]: Add Window Info -->
# <g id="node7" class="node">
# <title>[7]: Add Window Info</title>
# <polygon fill="none" stroke="blue" points="159.5,-512.09 19.5,-512.09 19.5,-476.09 159.5,-476.09 159.5,-512.09"/>
# <text text-anchor="middle" x="89.5" y="-490.39" font-family="Times,serif" font-size="14.00" fill="blue">[7]: Add Window Info</text>
# </g>
# <!-- pcoll6870&#45;&gt;[7]: Add Window Info -->
# <g id="edge6" class="edge">
# <title>pcoll6870&#45;&gt;[7]: Add Window Info</title>
# <path fill="none" stroke="black" d="M89.5,-547.78C89.5,-540.07 89.5,-530.8 89.5,-522.2"/>
# <polygon fill="black" stroke="black" points="93,-522.19 89.5,-512.19 86,-522.19 93,-522.19"/>
# </g>
# <!-- pcoll3252 -->
# <g id="node8" class="node">
# <title>pcoll3252</title>
# <ellipse fill="none" stroke="blue" cx="89.5" cy="-422.09" rx="18" ry="18"/>
# </g>
# <!-- [7]: Add Window Info&#45;&gt;pcoll3252 -->
# <g id="edge7" class="edge">
# <title>[7]: Add Window Info&#45;&gt;pcoll3252</title>
# <path fill="none" stroke="black" d="M89.5,-475.78C89.5,-468.07 89.5,-458.8 89.5,-450.2"/>
# <polygon fill="black" stroke="black" points="93,-450.19 89.5,-440.19 86,-450.19 93,-450.19"/>
# </g>
# <!-- [7]: Group By Window -->
# <g id="node9" class="node">
# <title>[7]: Group By Window</title>
# <polygon fill="none" stroke="blue" points="162,-368.09 17,-368.09 17,-332.09 162,-332.09 162,-368.09"/>
# <text text-anchor="middle" x="89.5" y="-346.39" font-family="Times,serif" font-size="14.00" fill="blue">[7]: Group By Window</text>
# </g>
# <!-- pcoll3252&#45;&gt;[7]: Group By Window -->
# <g id="edge8" class="edge">
# <title>pcoll3252&#45;&gt;[7]: Group By Window</title>
# <path fill="none" stroke="black" d="M89.5,-403.78C89.5,-396.07 89.5,-386.8 89.5,-378.2"/>
# <polygon fill="black" stroke="black" points="93,-378.19 89.5,-368.19 86,-378.19 93,-378.19"/>
# </g>
# <!-- pcoll4022 -->
# <g id="node10" class="node">
# <title>pcoll4022</title>
# <ellipse fill="none" stroke="blue" cx="89.5" cy="-278.09" rx="18" ry="18"/>
# </g>
# <!-- [7]: Group By Window&#45;&gt;pcoll4022 -->
# <g id="edge9" class="edge">
# <title>[7]: Group By Window&#45;&gt;pcoll4022</title>
# <path fill="none" stroke="black" d="M89.5,-331.78C89.5,-324.07 89.5,-314.8 89.5,-306.2"/>
# <polygon fill="black" stroke="black" points="93,-306.19 89.5,-296.19 86,-306.19 93,-306.19"/>
# </g>
# <!-- [7]: Write TFRecords -->
# <g id="node11" class="node">
# <title>[7]: Write TFRecords</title>
# <polygon fill="none" stroke="blue" points="157,-224.09 22,-224.09 22,-188.09 157,-188.09 157,-224.09"/>
# <text text-anchor="middle" x="89.5" y="-202.39" font-family="Times,serif" font-size="14.00" fill="blue">[7]: Write TFRecords</text>
# </g>
# <!-- pcoll4022&#45;&gt;[7]: Write TFRecords -->
# <g id="edge10" class="edge">
# <title>pcoll4022&#45;&gt;[7]: Write TFRecords</title>
# <path fill="none" stroke="black" d="M89.5,-259.78C89.5,-252.07 89.5,-242.8 89.5,-234.2"/>
# <polygon fill="black" stroke="black" points="93,-234.19 89.5,-224.19 86,-234.19 93,-234.19"/>
# </g>
# <!-- windowed_dataset -->
# <g id="node12" class="node">
# <title>windowed_dataset</title>
# <ellipse fill="none" stroke="blue" cx="89.5" cy="-76.04" rx="76.09" ry="76.09"/>
# <text text-anchor="middle" x="89.5" y="-72.34" font-family="Times,serif" font-size="14.00" fill="blue">windowed_dataset</text>
# </g>
# <!-- [7]: Write TFRecords&#45;&gt;windowed_dataset -->
# <g id="edge11" class="edge">
# <title>[7]: Write TFRecords&#45;&gt;windowed_dataset</title>
# <path fill="none" stroke="black" d="M89.5,-188.08C89.5,-180.96 89.5,-172.12 89.5,-162.54"/>
# <polygon fill="black" stroke="black" points="93,-162.35 89.5,-152.35 86,-162.35 93,-162.35"/>
# </g>
# </g>
# </svg>

# %%
# from apache_beam.runners import DataflowRunner

# runner = DataflowRunner()
# runner.run_pipeline(p, options=options)

with beam_impl.Context('/tmp'):
    p.run()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-13-cc480fdc7532> in <module>
#       5
#       6 with beam_impl.Context('/tmp'):
# ----> 7     p.run()
#
# ~/apache-beam-custom/packages/beam/sdks/python/apache_beam/pipeline.py in run(self, test_runner_api)
#     551         finally:
#     552           shutil.rmtree(tmpdir)
# --> 553       return self.runner.run_pipeline(self, self._options)
#     554     finally:
#     555       shutil.rmtree(self.local_tempdir, ignore_errors=True)
#
# ~/apache-beam-custom/packages/beam/sdks/python/apache_beam/runners/interactive/interactive_runner.py in run_pipeline(self, pipeline, options)
#     137
#     138     user_pipeline = ie.current_env().user_pipeline(pipeline)
# --> 139     pipeline_instrument = inst.build_pipeline_instrument(pipeline, options)
#     140
#     141     # The user_pipeline analyzed might be None if the pipeline given has nothing
#
# ~/apache-beam-custom/packages/beam/sdks/python/apache_beam/runners/interactive/pipeline_instrument.py in build_pipeline_instrument(pipeline, options)
#     865   pi = PipelineInstrument(pipeline, options)
#     866   pi.preprocess()
# --> 867   pi.instrument()  # Instruments the pipeline only once.
#     868   return pi
#     869
#
# ~/apache-beam-custom/packages/beam/sdks/python/apache_beam/runners/interactive/pipeline_instrument.py in instrument(self)
#     497           self._pipeline,
#     498           cacheable_input,
# --> 499           cacheable_input in unbounded_source_pcolls)
#     500     # Replace/wire inputs w/ cached PCollections from ReadCache transforms.
#     501     self._replace_with_cached_inputs(self._pipeline)
#
# ~/apache-beam-custom/packages/beam/sdks/python/apache_beam/runners/interactive/pipeline_instrument.py in _read_cache(self, pipeline, pcoll, is_unbounded_source_output)
#     701             | '{}{}'.format(READ_CACHE, key) >> cache.ReadCache(
#     702                 self._cache_manager, key)
# --> 703             | '{}{}unreify'.format(READ_CACHE, key) >> beam.ParDo(Unreify()))
#     704         self._cached_pcoll_read[key] = pcoll_from_cache
#     705     # else: NOOP when cache doesn't exist, just compute the original graph.
#
# ~/apache-beam-custom/packages/beam/sdks/python/apache_beam/transforms/ptransform.py in __ror__(self, pvalueish, _unused)
#    1026
#    1027   def __ror__(self, pvalueish, _unused=None):
# -> 1028     return self.transform.__ror__(pvalueish, self.label)
#    1029
#    1030   def expand(self, pvalue):
#
# ~/apache-beam-custom/packages/beam/sdks/python/apache_beam/transforms/ptransform.py in __ror__(self, left, label)
#     563     pvalueish = _SetInputPValues().visit(pvalueish, replacements)
#     564     self.pipeline = p
# --> 565     result = p.apply(self, pvalueish, label)
#     566     if deferred:
#     567       return result
#
# ~/apache-beam-custom/packages/beam/sdks/python/apache_beam/pipeline.py in apply(self, transform, pvalueish, label)
#     638       try:
#     639         old_label, transform.label = transform.label, label
# --> 640         return self.apply(transform, pvalueish)
#     641       finally:
#     642         transform.label = old_label
#
# ~/apache-beam-custom/packages/beam/sdks/python/apache_beam/pipeline.py in apply(self, transform, pvalueish, label)
#     681         transform.type_check_inputs(pvalueish)
#     682
# --> 683       pvalueish_result = self.runner.apply(transform, pvalueish, self._options)
#     684
#     685       if type_options is not None and type_options.pipeline_type_check:
#
# ~/apache-beam-custom/packages/beam/sdks/python/apache_beam/runners/interactive/interactive_runner.py in apply(self, transform, pvalueish, options)
#     125   def apply(self, transform, pvalueish, options):
#     126     # TODO(qinyeli, BEAM-646): Remove runner interception of apply.
# --> 127     return self._underlying_runner.apply(transform, pvalueish, options)
#     128
#     129   def run_pipeline(self, pipeline, options):
#
# ~/apache-beam-custom/packages/beam/sdks/python/apache_beam/runners/runner.py in apply(self, transform, input, options)
#     196       m = getattr(self, 'apply_%s' % cls.__name__, None)
#     197       if m:
# --> 198         return m(transform, input, options)
#     199     raise NotImplementedError(
#     200         'Execution of [%s] not implemented in runner %s.' % (transform, self))
#
# ~/apache-beam-custom/packages/beam/sdks/python/apache_beam/runners/runner.py in apply_PTransform(self, transform, input, options)
#     226   def apply_PTransform(self, transform, input, options):
#     227     # The base case of apply is to call the transform's expand.
# --> 228     return transform.expand(input)
#     229
#     230   def run_transform(self,
#
# ~/apache-beam-custom/packages/beam/sdks/python/apache_beam/runners/interactive/cache_manager.py in expand(self, pbegin)
#     305   def expand(self, pbegin):
#     306     # pylint: disable=expression-not-assigned
# --> 307     return pbegin | 'Read' >> self._cache_manager.source('full', self._label)
#     308
#     309
#
# ~/apache-beam-custom/packages/beam/sdks/python/apache_beam/runners/interactive/cache_manager.py in source(self, *labels)
#     254   def source(self, *labels):
#     255     return self._reader_class(
# --> 256         self._glob_path(*labels), coder=self.load_pcoder(*labels))
#     257
#     258   def sink(self, labels, is_capture=False):
#
# ~/apache-beam-custom/packages/beam/sdks/python/apache_beam/io/textio.py in __init__(self, file_pattern, min_bundle_size, compression_type, strip_trailing_newlines, coder, validate, skip_header_lines, **kwargs)
#     570         coder,
#     571         validate=validate,
# --> 572         skip_header_lines=skip_header_lines)
#     573
#     574   def expand(self, pvalue):
#
# ~/apache-beam-custom/packages/beam/sdks/python/apache_beam/io/textio.py in __init__(self, file_pattern, min_bundle_size, compression_type, strip_trailing_newlines, coder, buffer_size, validate, skip_header_lines, header_processor_fns)
#     129         min_bundle_size,
#     130         compression_type=compression_type,
# --> 131         validate=validate)
#     132
#     133     self._strip_trailing_newlines = strip_trailing_newlines
#
# ~/apache-beam-custom/packages/beam/sdks/python/apache_beam/io/filebasedsource.py in __init__(self, file_pattern, min_bundle_size, compression_type, splittable, validate)
#     126     self._splittable = splittable
#     127     if validate and file_pattern.is_accessible():
# --> 128       self._validate()
#     129
#     130   def display_data(self):
#
# ~/apache-beam-custom/packages/beam/sdks/python/apache_beam/options/value_provider.py in _f(self, *args, **kwargs)
#     133         if not obj.is_accessible():
#     134           raise error.RuntimeValueProviderError('%s not accessible' % obj)
# --> 135       return fnc(self, *args, **kwargs)
#     136
#     137     return _f
#
# ~/apache-beam-custom/packages/beam/sdks/python/apache_beam/io/filebasedsource.py in _validate(self)
#     189     match_result = FileSystems.match([pattern], limits=[1])[0]
#     190     if len(match_result.metadata_list) <= 0:
# --> 191       raise IOError('No files found based on the file pattern %s' % pattern)
#     192
#     193   def split(
#
# OSError: No files found based on the file pattern /tmp/it-1uxh2ztz140611056256912/full/078add12c1-140611049974800-140611049552400-140611056256912-*-of-*

# %%
# !gsutil ls gs://print-nanny-dev/dataflow/bounding-boxes-dev/
# Out:
# CommandException: One or more URLs matched no objects.
